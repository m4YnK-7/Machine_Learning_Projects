# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\Mayank Singh\\Desktop\\Stuff\\Machine_Learning_Projects\\Titanic_Survival_Predicition'

# %%
df = pd.read_csv("train.csv")
df_test = pd.read_csv("test.csv")

# %%
df_test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex
# 0          892       3                              Kelly, Mr. James    male  \
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
# df_test = df_test.drop(['Name','Cabin','Fare','Ticket'],axis = 1)
average_age = df_test['Age'].sum()/len(df_test['Age'])
df_test['Age'] = df_test['Age'].fillna(average_age)
# df_test = df_test.drop(['Fare','Ticket'],axis = 1)
df_test['Age'] = df_test['Age'].round(2)

df_test_nums = df_test.select_dtypes(exclude='object')
df_test_objs = df_test.select_dtypes(include='object')
df_test_objs = pd.get_dummies(df_test_objs,drop_first=True)
final_df_test = pd.concat([df_test_nums,df_test_objs],axis=1)
final_df_test.set_index('PassengerId')
# Out:
#              Pclass    Age  SibSp  Parch  Sex_male  Embarked_Q  Embarked_S
# PassengerId
# 892               3  34.50      0      0      True        True       False
# 893               3  47.00      1      0     False       False        True
# 894               2  62.00      0      0      True        True       False
# 895               3  27.00      0      0      True       False        True
# 896               3  22.00      1      1     False       False        True
# ...             ...    ...    ...    ...       ...         ...         ...
# 1305              3  24.04      0      0      True       False        True
# 1306              1  39.00      0      0     False       False       False
# 1307              3  38.50      0      0      True       False        True
# 1308              3  24.04      0      0      True       False        True
# 1309              3  24.04      1      1      True       False       False
#
# [418 rows x 7 columns]

# %%
final_df_test
# Out:
#      PassengerId  Pclass    Age  SibSp  Parch  Sex_male  Embarked_Q
# 0            892       3  34.50      0      0      True        True  \
# 1            893       3  47.00      1      0     False       False
# 2            894       2  62.00      0      0      True        True
# 3            895       3  27.00      0      0      True       False
# 4            896       3  22.00      1      1     False       False
# ..           ...     ...    ...    ...    ...       ...         ...
# 413         1305       3  24.04      0      0      True       False
# 414         1306       1  39.00      0      0     False       False
# 415         1307       3  38.50      0      0      True       False
# 416         1308       3  24.04      0      0      True       False
# 417         1309       3  24.04      1      1      True       False
#
#      Embarked_S
# 0         False
# 1          True
# 2         False
# 3          True
# 4          True
# ..          ...
# 413        True
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass
# 0            1         0       3  \
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp
# 0                            Braund, Mr. Owen Harris    male  22.0      1  \
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
len(df[df['Cabin'].isnull() == True])
# Out:
# 687

# %%
df.set_index('PassengerId')
df = df.drop(['Name','Cabin'],axis = 1)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch
# 0            1         0       3    male  22.0      1      0  \
# 1            2         1       1  female  38.0      1      0
# 2            3         1       3  female  26.0      0      0
# 3            4         1       1  female  35.0      1      0
# 4            5         0       3    male  35.0      0      0
#
#              Ticket     Fare Embarked
# 0         A/5 21171   7.2500        S
# 1          PC 17599  71.2833        C
# 2  STON/O2. 3101282   7.9250        S
# 3            113803  53.1000        S
# 4            373450   8.0500        S

# %%
m = df[df['Sex']=='male']
m['Age'].sum()/len(m['Age'])
# Out:
# 24.123344887348352

# %%
m = df[df['Sex']=='female']
m['Age'].sum()/len(m['Age'])
# Out:
# 23.203821656050955

# %%
average_age = df['Age'].sum()/len(df['Age'])

# %%
df['Age'] = df['Age'].fillna(average_age)

# %%
df = df.drop(['Fare','Ticket'],axis = 1)
df['Age'] = df['Age'].round(2)

# %%
df
# Out:
#      PassengerId  Survived  Pclass     Sex   Age  SibSp  Parch Embarked
# 0              1         0       3    male  22.0      1      0        S
# 1              2         1       1  female  38.0      1      0        C
# 2              3         1       3  female  26.0      0      0        S
# 3              4         1       1  female  35.0      1      0        S
# 4              5         0       3    male  35.0      0      0        S
# ..           ...       ...     ...     ...   ...    ...    ...      ...
# 886          887         0       2    male  27.0      0      0        S
# 887          888         1       1  female  19.0      0      0        S
# 888          889         0       3  female  23.8      1      2        S
# 889          890         1       1    male  26.0      0      0        C
# 890          891         0       3    male  32.0      0      0        Q
#
# [891 rows x 8 columns]

# %%
df.select_dtypes(include='object')
# Out:
#         Sex Embarked
# 0      male        S
# 1    female        C
# 2    female        S
# 3    female        S
# 4      male        S
# ..      ...      ...
# 886    male        S
# 887  female        S
# 888  female        S
# 889    male        C
# 890    male        Q
#
# [891 rows x 2 columns]

# %%
df_nums = df.select_dtypes(exclude='object')
df_objs = df.select_dtypes(include='object')

# %%
df_nums.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Age          891 non-null    float64
#  4   SibSp        891 non-null    int64
#  5   Parch        891 non-null    int64
# dtypes: float64(1), int64(5)
# memory usage: 41.9 KB

# %%
df_objs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Sex       891 non-null    object
#  1   Embarked  889 non-null    object
# dtypes: object(2)
# memory usage: 14.0+ KB

# %%
df_objs = pd.get_dummies(df_objs,drop_first=True)

# %%
final_df = pd.concat([df_nums,df_objs],axis=1)

# %%
final_df.set_index('PassengerId')
# Out:
#              Survived  Pclass   Age  SibSp  Parch  Sex_male  Embarked_Q
# PassengerId
# 1                   0       3  22.0      1      0      True       False  \
# 2                   1       1  38.0      1      0     False       False
# 3                   1       3  26.0      0      0     False       False
# 4                   1       1  35.0      1      0     False       False
# 5                   0       3  35.0      0      0      True       False
# ...               ...     ...   ...    ...    ...       ...         ...
# 887                 0       2  27.0      0      0      True       False
# 888                 1       1  19.0      0      0     False       False
# 889                 0       3  23.8      1      2     False       False
# 890                 1       1  26.0      0      0      True       False
# 891                 0       3  32.0      0      0      True        True
#
#              Embarked_S
# PassengerId
# 1                  True
# 2                 False
# ...

# %%
X = final_df.drop('Survived',axis = 1)
y = final_df['Survived']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_predictions = model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error
MAE = mean_absolute_error(y_test,test_predictions)
MSE = mean_squared_error(y_test,test_predictions)
RMSE = np.sqrt(MSE)
print(MAE,MSE,RMSE,sep = "\n")
# Out:
# 0.29833818828364417
# 0.15208318663987574
# 0.38997844381436747

# %%
test_predictions[test_predictions>0.5] = 1
test_predictions[test_predictions<=0.5] = 0

# %%
# final model
final_model = LinearRegression()
final_model.fit(X,y)
# Out:
# LinearRegression()

# %%
test_pred = final_model.predict(final_df_test)

# %%
test_pred[test_pred>=0.5] = 1
test_pred[test_pred<0.5] = 0

# %%
arr = []
for i in range(len(test_pred)):
    arr.append([892+i,int(test_pred[i])])

# %%
import csv

# Specify the file name
filename = 'output.csv'

# Writing to csv file
with open(filename, 'w', newline='') as file:
    writer = csv.writer(file)
    
    # Writing the data
    writer.writerows(arr)

print(f"Data has been written to {filename}")
# Out:
# Data has been written to output.csv
